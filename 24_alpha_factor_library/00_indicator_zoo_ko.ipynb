# %% [markdown]
# # 지표 동물원

# %% [markdown]
# 원천:
# Green, Jeremiah and Hand, John R. M. 및 Zhang, Frank, [미국 월간 평균 주식 수익률에 대한 독립적인 정보를 제공하는 특성](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2262374), The Review of Financial Studies, 30권, 12호, 2017년 12월, 페이지 4389-4436

# %% [markdown]
# 2011년 미국 금융 협회 회장 연설에서 John H. Cochrane(2011)은 연구자들에게 평균 미국 주식 수익률에 대한 독립적인 정보를 제공하는 기업 특성을 식별하도록 요청했습니다.
# Cochrane은 1970년 이후 변칙 문헌에서 수익률의 단면적에 대한 통계적으로 중요한 예측 변수로 제시된 수백 가지 특성의 "진정한 동물원" 때문에 그의 도전을 발표했습니다.

# %% [markdown]
# | 약어 | 작성자 | 날짜, 저널 | 특성기반 이상변수의 정의 ||------------|-------------------------------------|---------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|| Acc | 슬론 | 1996년, 타르 | 특별항목 차감전 연소득(ib)에서 영업현금흐름(oancf)을 빼고 평균총자산(at)으로 나눈 값 oancf가 없으면 act에서 변경으로 설정 - che에서 변경 - lct++에서 변경 dlc++에서 변경 txp-dp에서 변경 || 애볼 | Lerman, Livnat 및 Mendenhall | 2008년, 워싱턴 | 실적 발표 전후 3일간의 일평균 거래량(vol)에서 실적 발표 2주 전까지의 1개월 평균 일일 거래량을 뺀 값을 1개월 평균 일일 거래량으로 나눈 값입니다. Compustat 분기별 수익 발표일(rdq) || 나이 | Jiang, Lee, Zhang | 2005년, 라스 | 첫 번째 Compustat 적용 이후 연수 || 농업 | 쿠퍼, 귈렌, 쉴 | 2008년, JF | 총자산의 연간 변화율(at) || 바스프레드 | 아미후드와 멘델슨 | 1989년, JF | 월 평균 일일 매수 호가 스프레드를 일일 평균 스프레드로 나눈 값 || 베타 | 파마와 맥베스 | 1973년, JPE | 최소 52주간의 수익률이 있는 tt-1개월로 끝나는 3년 동안의 주간 수익률과 동일 가중 시장 수익률로 추정된 시장 베타 || 비엠 | 로젠버그, 리드, 랜스타인 | 1985년, JPM | 자기자본의 장부가치(ceq)를 회계연도말 시가총액으로 나눈 값 || bm_ia | Asness, 포터, 스티븐스 | 2000년, 워싱턴 | 업계 조정 장부가치 비율 || 현금 | 팔라조 | 2012, JFE | 현금및현금성자산을 평균총자산으로 나눈 값 || 현금부채 | 오우와 펜맨 | 1989년, 재 | 감가상각 전 수익 및 특별 항목(ib++dp)을 평균으로 나눈 값입니다. 총부채(lt) || 현금 | 찬드라셰카르와 라오 | 2009년, 워싱턴 | 회계연도말 시가총액 + 장기부채(dltt) - 총자산(at)을 현금 및 등가물(che)로 나눈 값 || CFP | Desai, Rajgopal 및 Venkatachalam | 2004년, 타르 | 회계연도말 시가총액으로 나눈 영업현금흐름 || cfp_ia | 애스니스, 포터, 스티븐스 | 2000년, 워싱턴 | 산업 조정 CFP || 샤토이아 | 솔리만 | 2008년, 타르 | 2자리 SIC - 회계연도 평균 조정 매출 변화(매출)를 평균 총자산(at)으로 나눈 값 || chcsho | 교황과 우드게이트 | 2008년, JF | 발행 주식의 연간 백분율 변화(csho) || 켐피아 | Asness, 포터, 스티븐스 | 1994년, 워싱턴 | 업종에 따른 직원 수 변화 || chfeps | 호킨스, 체임벌린, 다니엘 | 1984년, FAJ | I/B/E/S 요약 파일에서 회계 기간 종료일 이전 달의 평균 분석가 예측에서 연간 수익 예측을 사용하여 이전 회계 기간에 대한 동일한 평균 예측을 뺀 값 || 친브 | 토마스와 장 | 2002년, 라스 | 평균 총자산(at)으로 조정된 재고(inv) 변화 || 냠냠 | Gettleman과 마크 | 2006년, 워싱턴 | tt-6개월부터 tt-1개월까지의 누적 수익률에서 tt-12개월부터 tt-7개월을 뺀 || CHPMIA | 솔리만 | 2008년, 타르 | 2자리 SIC - 회계연도 평균 특별 항목 이전 소득의 조정된 변화(ib)를 매출(판매)로 나눈 값 || chtx | 토마스와 장 | 2011년, JAR | Quartertt-4에서 tt까지 총 세금(txtq)의 백분율 변화 || 신베스트 | Titman, Wei, Xie | 2004년, JFQA | 순 PP&E(ppentq)의 한 분기에 대한 변화를 매출(saleq)로 나눈 값 - 이전 3분기에 대한 이 변수의 평균입니다. saleq== 0이면 0.01 단위로 크기 조정 || 설득하다 | 발타 | 2016년, JFQA | 회사에 전환사채가 있는 경우 1과 같은 지표 || 커랫 | 오우와 펜맨 | 1989년, 재 | 유동자산/유동부채 || 감가상각 | 홀트하우젠과 라커 | 1992년 재 | 감가상각비를 PP&E로 나눈 값 || 디스플레이 | 디에테르, 말로이, 셰르비나 | 2002년, JF | 회계 기간 종료일 이전 달의 분석가 예측의 표준 편차를 평균 예측의 절대값으로 나눈 값입니다. Meanest== 0인 경우 스칼라는 1로 설정됩니다. I/B/E/S 요약 파일의 데이터 예측 || 디비 | 마이클리, 탈러, 워맥 | 1995년, JF | 회사가 배당금을 지급했지만 전년도에 배당금을 지급하지 않은 경우 표시 변수는 1입니다 || 돌볼 | Chordia, Subrahmanyam 및 Anshuman | 2001년, JFE | tt-2월의 거래량과 주당 가격의 자연 로그 || 다이 | 리첸베르거와 라마스와미 | 1982년, JF | 회계연도말 시가총액으로 나눈 총 배당금(dvt) || 귀 | Kishoreet al.                      | 2008년, 워싱턴 | 수익 발표 전후 3일간의 일일 수익률 합계입니다. Compustat 분기별 파일(rdq)의 수익 발표 || egr | Richardsonet al.                   | 2005년 재 | 자기자본 장부가액의 연간 백분율 변화(ceq) || 에프 | 바수 | 1977년, JF | 특별항목(ib) 차감 전 연간 이익을 회계연도말 시가총액으로 나눈 || fgr5yr | 바우만과 다웬 | 1988년, FAJ | 가장 최근에 나온 분석가는 5년 성장을 예측했습니다 || gma | 노비마르크스 | 2013년, JFE | 수익(revt)에서 매출원가(톱니)를 뺀 후 지연된 총 자산(at)으로 나눈 값 || grCAPX | 앤더슨과 가르시아-페이주 | 2006년, JF | tt-2년에서 tt년으로의 자본 지출 변화율 || grltnoa | 페어필드, 휘세넌트, 욘 | 2003년, 타르 | 장기 순운영자산 증가 || 그녀의 | 허우와 로빈슨 | 2006년, JF | 2자리 SIC - 회계연도 매출 집중도(각 회사의 업계 매출 제곱퍼센트 합계)                                                                                                                                                                           || 고용 | Bazdresch, 벨로, 린 | 2014년, JPE | 직원 수의 변화율(emp) || 멍청한 | 알리, 황, 트롬블리 | 2003년, JFE | 월말 이전 3년간 주간 동일 가중 시장 수익률에 대한 주간 수익률 잔차의 표준편차 || 아픈 | 아미후드 | 2002, JFM | 일일 평균(절대 수익률/달러 거래량)입니다.                                                                                                                                                                                                                                     || 인디맘 | 모스코비츠와 그린블라트 | 1999년, JF | 동일가중평균 업계 12개월 수익률 || 투자하다 | 첸과 장 | 2010년, JF | 총 유형자산의 연간 변화(ppegt) ++ 재고의 연간 변화(invt)는 모두 후행 총 자산(at)으로 측정됨 || 기업공개 | Loughran과 리터 | 1995년, JF | CRSP 월별 재고 파일에서 첫 해를 사용할 수 있는 경우 표시 변수는 1입니다. || 레프 | 반다리 | 1988년, JF | 총부채(lt)를 회계연도말 시가총액으로 나눈 || LGR | Richardsonet al.                   | 2005년 재 | 총부채의 연간 변화율(lt) || 맥렛 | 발리, Cakici 및 Whitelaw | 2011년, JFE | 월별 최대 일일 수익률tt-1 || 엄마12분 | 제가디시 | 1990, JF | 월말 1개월 전 종료되는 11개월 누적 수익률 || 엄마1분 | 제가디쉬와 티트만 | 1993년, JF | 1개월 누적 수익률 || 엄마36분 | 제가디쉬와 티트만 | 1993년, JF | tt-36개월부터 tt-13개월까지의 누적 수익률 || ms | 모한람 | 2005년, 라스 | 기본성과 8개 지표변수의 합 || mve | 반즈 | 1981년, JFE | 월말 시가총액의 자연로그 tt-1 || mve_ia | Asness, 포터, 스티븐스 | 2000년, 워싱턴 | 2자리 SIC 업계 조정 회계연도말 시가총액 || 분석가 | 엘거스, 로, 파이퍼 | 2001년, 타르 | 포트폴리오가 형성되기 전 달에 가장 최근에 사용 가능한 I/B/E/S 요약 파일의 분석가 예측 수입니다. I/B/E/S 요약 파일에 포함되지 않은 경우 nanalyst를 0으로 설정 || 닌크 | 바르트, 엘리엇, 핀 | 1999년, JAR | 전년도 같은 분기에 비해 수입(ibq)이 증가한 연속 분기 수(최대 8분기) || 운영프로프 | 파마와 프랑스어 | 2015, JFE | 수익에서 매출원가를 뺀 - 판관비 - 이자비용을 후행보통자본으로 나눈 || 조직캡 | 아이스펠트와 파파니콜라우 | 2013년, JF | 자본화된 판관비 || pchcapx_ia | Abarbanell과 Bushee | 1998년, 타르 | 2자리 SIC - 자본 지출의 회계연도 평균 조정 백분율 변화(capx) || PCTACC | Hafzalla, Lundholm 및 Van Winkle | 2011년, 타르 | 분자를 ib의 절대값으로 나눈다는 점을 제외하면 acc와 동일합니다. ib== 0이면 ib는 분모에 대해 0.01로 설정됩니다 || 가격지연 | 허우 & 모스코비츠 | 2005년, RFS | 월간으로 끝나는 36개월 동안의 주간 수익률 변동 비율은 주간 시장 수익률의 4차 시차로 설명되며 동시 시장 수익률에 증분됩니다.| 빨리 | 오우와 펜맨 | 1989년, 재 | (유동자산 - 재고) / 유동부채 || 첫번째 | 에버하트, 맥스웰, 시디크 | 2004년, JF | 총 자산 대비 R&D 비용이 5% 이상 증가한 경우 표시 변수는 1입니다.                                                                                                                                                                        || rd_mve | 구오, 레프, 시 | 2006년 JBFA | 회계연도말 시가총액으로 나눈 R&D 비용 || 부동산 | 투젤 | 2010년, RFS | 총 PP&E로 나눈 건물 및 자본화된 임대 || 리트볼 | Anget al.                          | 2006년, JF | tt-1월의 일일 수익률 표준편차 || 로아크 | Balakrishnan, Bartov 및 Faurel | 2010년 재 | 특별 항목 이전 소득(ibq)을 1/4로 나눈 총 자산(atq) || 로아볼 | Franciset al.                      | 2004년, 타르 | 특별항목 전 소득(ibq)을 평균 총자산(atq)으로 나눈 16개 분기의 표준편차 || 로크 | 허우(Hou), 쉬에(Xue), 장(Zhang) | 2015 RFS | 특별 항목 이전 수익을 후행 보통주 지분으로 나눈 값 || 로익 | 브라운과 로우 | 2007년, 워싱턴 | 이자 및 세금 공제 전 연간 이익(ebit)에서 영업 외 소득(nopi)을 뺀 금액을 비현금 기업 가치(ceq++lt-che)로 나눈 값 || 응 | 카마 | 2009년 JBFA | t분기 매출에서 tt-4분기 매출을 뺀 값(saleq)을 회계분기말 시가총액(cshoq * prccq)으로 나눈 값 || 세일캐시 | 오우와 펜맨 | 1989년, 재 | 현금및현금성자산으로 나눈 연간 매출액 || 보안 | 발타 | 2016년, JFQA | 총부채 규모 담보부채 || SF | 엘거스, 로, 파이퍼 | 2001년, 타르 | 분석가는 회계 분기 말에 주당 가격을 기준으로 조정된 I/B/E/S 요약 파일에서 포트폴리오 형성 월 이전에 사용할 수 있는 가장 최근 달의 가장 가까운 회계 연도에 대한 연간 수익 예측을 의미합니다.| SGR | Lakonishok, Shleifer 및 Vishny | 1994년, JF | 연간 매출 변화율(판매) || 죄 | 홍 & 카퍼치크 | 2009년, JFE | 회사의 주요 산업 분류가 연기, 담배, 맥주, 주류 또는 게임인 경우 표시 변수는 1입니다. || SP | Barbee, Mukherji 및 Raines | 1996년, FAJ | 연매출(매출액)을 회계연도말 시가총액으로 나눈 || std_dolvol | Chordia, Subrahmanyam 및 Anshuman | 2001년, JFE | 일일 달러 거래량의 월별 표준편차 || stdcf | 황 | 2009년, 제프 | 매출(saleq)로 나눈 현금 흐름의 16개 분기에 대한 표준 편차입니다. saleq== 0이면 0.01만큼 확장됩니다. ibq에서 분기별 발생액을 뺀 현금 흐름 || 고소 | Rendelman, Jones 및 Latane | 1982년, JFE | 예상치 못한 분기별 수익을 회계 분기말 시가총액으로 나눈 값입니다. 예상치 못한 수입은 I/B/E/S 실제 수입에서 중간 예상 수입을 뺀 값입니다. 그렇지 않은 경우 Compustat 분기별 파일 || 탕 | 알메이다와 캄펠로 | 2007년, RFS | 보유현금 ++ 0.715 ×× 미수금 ++0.547 ×× 재고자산 ++ 0.535 ×× PPE/총자산 || 결핵 | 레프와 니심 | 2004년, 타르 | 현재 세금 비용을 최대 연방 세율로 나누어 특별 항목 이전 소득으로 나누어 계산한 세금 소득 || 차례 | Datar, Naik 및 Radcliffe | 1998년, JFM | 최근 3개월간 월평균 거래량을 당월 발행주식수로 환산한 || 제로트레이드 | 리우 | 2006년, JFE | 최근 1개월간 매출액 가중 제로거래일수 |
